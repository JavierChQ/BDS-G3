# %% [markdown]
# # Funciones comunes en numpy

# %%
import numpy as np

# %% [markdown]
# # Shape y reshape

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[7, 9],
#        [9, 2],
#        [8, 6]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[7, 9, 9, 2, 8, 6]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # Max y argmax

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([13, 14, 18,  2, 10, 13,  8,  8,  8, 11])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[13, 14, 18,  2, 10],
#        [13,  8,  8,  8, 11]])

# %%
arr.max()
# Out:
# 18

# %%
matriz.max()
# Out:
# 18

# %%
matriz.max(1)
# Out:
# array([18, 13])

# %%
arr.argmax()
# Out:
# 2

# %%
matriz.argmax()
# Out:
# 2

# %% [markdown]
# # Min y argmin

# %%
arr.min()
# Out:
# 2

# %%
arr.argmin()
# Out:
# 3

# %%
matriz.min(0)
# Out:
# array([13,  8,  8,  2, 10])

# %% [markdown]
# # Sort

# %%
arr
# Out:
# array([13, 14, 18,  2, 10, 13,  8,  8,  8, 11])

# %%
arr.sort()
arr
# Out:
# array([ 2,  8,  8,  8, 10, 11, 13, 13, 14, 18])

# %% [markdown]
# # Median

# %%
np.median(arr)
# Out:
# 10.5

# %% [markdown]
# # Desviacion estandar std

# %%
np.std(arr)
# Out:
# 4.153311931459037

# %% [markdown]
# # Varianza var

# %%
np.var(arr)
# Out:
# 17.25
